# %%
import matplotlib.pyplot as plt
import torch
import seaborn as sns
import networkx as nx
import pandas
import json, os
import numpy as np
from sklearn.model_selection import train_test_split
# %matplotlib inline
sns.set()

# %%
def parse_graph(inpath, outpath, save = True):
    df = pandas.DataFrame(columns=['id1', 'id2'])
    with open(inpath, 'r') as f:
        line = f.readline()
        cnt = 1
        while line:
            df.loc[cnt] = line.strip().split("\t")
            line = f.readline()
            cnt += 1
    df['weight'] = 1
    if save:
        df.to_csv(os.path.join(outpath, 'data.csv'), index=False)
        train, test = train_test_split(df, train_size = 0.8)
        train.to_csv(os.path.join(outpath, 'train.csv'), index=False)
        test.to_csv(os.path.join(outpath, 'test.csv'), index=False)
    return df

# %%
df = parse_graph('resources/physics/CA-GrQc.txt', 
                 'resources/physics/')

# %%
len(df['id1'].unique())
# Out:
# 5242

# %%
sorted(df['id1'].unique())
# Out:
# ['1000',
#  '10000',
#  '10002',
#  '10004',
#  '10022',
#  '10024',
#  '10026',
#  '10039',
#  '10041',
#  '10055',
#  '10056',
#  '1006',
#  '10062',
#  '1008',
#  '10081',
#  '10096',
#  '1010',
#  '10113',
#  '10115',
#  '10116',
#  '10117',
#  '1013',
#  '10130',
#  '10133',
#  '10134',
#  '1014',
#  '10148',
#  '10153',
#  '10154',
#  '10158',
#  '10162',
#  '10163',
#  '10178',
#  '10180',
#  '10183',
#  '10186',
#  '10211',
#  '1023',
#  '10235',
#  '1024',
#  '10243',
#  '10246',
#  '10247',
#  '1025',
#  '10251',
#  '10252',
#  '10253',
#  '1026',
#  '10268',
#  '1028',
#  '1029',
#  '10310',
#  '10317',
#  '10338',
#  '10341',
#  '10346',
#  '10350',
#  '10351',
#  '10352',
#  '10354',
#  '10355',
#  '10356',
#  '10358',
#  '10376',
#  '10381',
#  '10382',
#  '10383',
#  '10388',
#  '10390',
#  '10391',
#  '10406',
#  '10407',
#  '10412',
#  '10427',
#  '10432',
#  '10433',
#  '10435',
#  '10438',
#  '10439',
#  '1044',
#  '10445',
#  '10446',
#  '1045',
#  '10456',
#  '10458',
#  '10463',
#  '10467',
#  '10468',
#  '10476',
#  '10477',
#  '10478',
#  '1048',
#  '10490',
#  '10496',
#  '10497',
#  '10499',
#  '1050',
#  '10500',
#  '10501',
#  '1051',
#  '10513',
#  '10514',
#  '10517',
#  '10519',
#  '10522',
#  '10524',
#  '10526',
#  '10532',
#  '10539',
#  '10543',
#  '10549',
#  '10550',
#  '10552',
#  '10555',
#  '10559',
#  '10561',
#  '10564',
#  '1058',
#  '10588',
#  '1059',
#  '10590',
#  '10597',
#  '106',
#  '10600',
#  '10601',
#  '10602',
#  '10615',
#  '10620',
#  '10623',
#  '10637',
#  '10638',
#  '10640',
#  '10652',
#  '10655',
#  '10656',
#  '10657',
#  '10672',
#  '10676',
#  '10677',
#  '10679',
#  '10682',
#  '10684',
#  '10711',
#  '10719',
#  '10726',
#  '1073',
#  '1074',
#  '1075',
#  '10762',
#  '10763',
#  '10765',
#  '1078',
#  '10791',
#  '10792',
#  '10794',
#  '10801',
#  '10805',
#  '10807',
#  '10818',
#  '10819',
#  '10822',
#  '10824',
#  '10825',
#  '10841',
#  '10842',
#  '10847',
#  '10850',
#  '10871',
#  '10872',
#  '10878',
#  '10879',
#  '10880',
#  '10881',
#  '10884',
#  '10895',
#  '10896',
#  '10897',
#  '10898',
#  '1090',
#  '10904',
#  '10906',
#  '10907',
#  '10910',
#  '10912',
#  '10918',
#  '10919',
#  '1092',
#  '10923',
#  '10925',
#  '10926',
#  '1093',
#  '10931',
#  '10936',
#  '10942',
#  '10956',
#  '10966',
#  '10967',
#  '10969',
#  '1098',
#  '10983',
#  '10986',
#  '10990',
#  '10991',
#  '10996',
#  '11002',
#  '11009',
#  '1101',
#  '11011',
#  '11012',
#  '11015',
#  '11016',
#  '11017',
#  '11026',
#  '11028',
#  '11030',
#  '11032',
#  '11034',
#  '11035',
#  '11037',
#  '1104',
#  '11047',
#  '1105',
#  '11052',
#  '11053',
#  '11054',
#  '11066',
#  '1107',
#  '11077',
#  '11082',
#  '1109',
#  '11093',
#  '11102',
#  '11107',
#  '11108',
#  '11109',
#  '11112',
#  '11113',
#  '11114',
#  '11120',
#  '11121',
#  '11125',
#  '11132',
#  '11141',
#  '11148',
#  '11152',
#  '1116',
#  '11175',
#  '11182',
#  '11183',
#  '11186',
#  '11194',
#  '11196',
#  '11197',
#  '11199',
#  '11213',
#  '11215',
#  '11216',
#  '11223',
#  '11227',
#  '11231',
#  '11233',
#  '1124',
#  '11241',
#  '1125',
#  '11275',
#  '11279',
#  '11280',
#  '11284',
#  '11285',
#  '11293',
#  '113',
#  '11318',
#  '11325',
#  '11328',
#  '11372',
#  '11379',
#  '114',
#  '11400',
#  '11401',
#  '11402',
#  '11403',
#  '11405',
#  '11410',
#  '11411',
#  '11416',
#  '11418',
#  '11426',
#  '11427',
#  '11442',
#  '11444',
#  '11445',
#  '11447',
#  '11459',
#  '11461',
#  '11462',
#  '11464',
#  '11465',
#  '11467',
#  '11468',
#  '11470',
#  '11472',
#  '1149',
#  '11490',
#  '11491',
#  '11493',
#  '11495',
#  '115',
#  '1150',
#  '11502',
#  '1151',
#  '11522',
#  '11528',
#  '1153',
#  '11537',
#  '11539',
#  '1154',
#  '11557',
#  '11561',
#  '11563',
#  '11566',
#  '1157',
#  '11572',
#  '11577',
#  '11579',
#  '11583',
#  '11591',
#  '11593',
#  '11602',
#  '11604',
#  '11607',
#  '11609',
#  '11610',
#  '11611',
#  '11612',
#  '11613',
#  '11616',
#  '11617',
#  '11621',
#  '11622',
#  '11623',
#  '11626',
#  '11629',
#  '11630',
#  '11631',
#  '11638',
#  '11640',
#  '11641',
#  '11642',
#  '11661',
#  '11662',
#  '11664',
#  '11670',
#  '11696',
#  '11700',
#  '11712',
#  '11713',
#  '11718',
#  '11719',
#  '1172',
#  '11721',
#  '11733',
#  '11734',
#  '1174',
#  '11746',
#  '11785',
#  '11788',
#  '11791',
#  '11792',
#  '11801',
#  '11806',
#  '11808',
#  '11811',
#  '11812',
#  '11815',
#  '11816',
#  '11820',
#  '11821',
#  '11822',
#  '11823',
#  '11824',
#  '11828',
#  '11829',
#  '11840',
#  '11841',
#  '11842',
#  '11844',
#  '1186',
#  '11861',
#  '11863',
#  '11865',
#  '11868',
#  '1187',
#  '11876',
#  '11878',
#  '11879',
#  '11891',
#  '11892',
#  '11893',
#  '11898',
#  '11899',
#  '11902',
#  '11903',
#  '11910',
#  '11911',
#  '11919',
#  '11923',
#  '11924',
#  '11925',
#  '11926',
#  '11929',
#  '11939',
#  '1194',
#  '11944',
#  '11951',
#  '11964',
#  '11965',
#  '11967',
#  '11968',
#  '11969',
#  '11971',
#  '11979',
#  '11991',
#  '12016',
#  '12017',
#  '12032',
#  '12034',
#  '12040',
#  '12041',
#  '12042',
#  '12043',
#  '12045',
#  '12046',
#  '12049',
#  '12050',
#  '12051',
#  '12053',
#  '12054',
#  '12056',
#  '12065',
#  '12066',
#  '12070',
#  '12071',
#  '12074',
#  '12085',
#  '12101',
#  '12106',
#  '12107',
#  '12110',
#  '12112',
#  '12113',
#  '12118',
#  '12121',
#  '12122',
#  '12130',
#  '12135',
#  '12141',
#  '12149',
#  '12151',
#  '12155',
#  '12157',
#  '12158',
#  '12160',
#  '12161',
#  '12165',
#  '12166',
#  '1217',
#  '12187',
#  '12192',
#  '12193',
#  '122',
#  '12212',
#  '12213',
#  '12235',
#  '12247',
#  '12248',
#  '12252',
#  '12256',
#  '12260',
#  '12262',
#  '12263',
#  '12266',
#  '12268',
#  '12286',
#  '12287',
#  '1229',
#  '12290',
#  '12291',
#  '12295',
#  '12296',
#  '123',
#  '12302',
#  '12306',
#  '12307',
#  '12308',
#  '12311',
#  '12312',
#  '12313',
#  '12318',
#  '12320',
#  '12321',
#  '12324',
#  '12334',
#  '12337',
#  '12338',
#  '1234',
#  '12365',
#  '12369',
#  '12370',
#  '12373',
#  '12380',
#  '12386',
#  '12387',
#  '12389',
#  '124',
#  '12406',
#  '12409',
#  '12411',
#  '12414',
#  '12419',
#  '12422',
#  '12423',
#  '12425',
#  '12453',
#  '12458',
#  '12460',
#  '12472',
#  '12473',
#  '12478',
#  '1248',
#  '12491',
#  '12492',
#  '12496',
#  '12498',
#  '12503',
#  '12504',
#  '12507',
#  '12512',
#  '1254',
#  '12545',
#  '12547',
#  '12551',
#  '12552',
#  '12553',
#  '12554',
#  '1258',
#  '12587',
#  '12599',
#  '12606',
#  '12611',
#  '12612',
#  '12614',
#  '12615',
#  '12616',
#  '12617',
#  '12618',
#  '12627',
#  '12637',
#  '12639',
#  '12640',
#  '12641',
#  '12642',
#  '12644',
#  '12645',
#  '1265',
#  '12654',
#  '12659',
#  '12660',
#  '12664',
#  '12665',
#  '1267',
#  '12675',
#  '12676',
#  '12678',
#  '12679',
#  '12687',
#  '12688',
#  '12689',
#  '12691',
#  '12695',
#  '12696',
#  '12701',
#  '12703',
#  '12704',
#  '12707',
#  '12709',
#  '12710',
#  '12712',
#  '12720',
#  '12722',
#  '12733',
#  '12735',
#  '12739',
#  '12742',
#  '12743',
#  '12745',
#  '12749',
#  '12751',
#  '12758',
#  '12763',
#  '1278',
#  '12781',
#  '12786',
#  '12787',
#  '12788',
#  '1279',
#  '12797',
#  '12798',
#  '128',
#  '1280',
#  '12801',
#  '12802',
#  '12803',
#  '12806',
#  '1281',
#  '12842',
#  '12849',
#  '12851',
#  '12852',
#  '12860',
#  '12861',
#  '12863',
#  '12865',
#  '12866',
#  '12868',
#  '12874',
#  '12884',
#  '12885',
#  '12887',
#  '1289',
#  '1292',
#  '12927',
#  '12928',
#  '1293',
#  '12930',
#  '12938',
#  '12940',
#  '12968',
#  '12971',
#  '12980',
#  '12981',
#  '13',
#  '13008',
#  '13010',
#  '13012',
#  '13013',
#  '13022',
#  '13026',
#  '13029',
#  '13031',
#  '13032',
#  '13034',
#  '13035',
#  '13036',
#  '13056',
#  '13060',
#  '13067',
#  '13068',
#  '13096',
#  '1310',
#  '1311',
#  '13142',
#  '13144',
#  '13153',
#  '13164',
#  '13167',
#  '13174',
#  '13175',
#  '13177',
#  '13190',
#  '13191',
#  '13196',
#  '13199',
#  '13202',
#  '13205',
#  '1321',
#  '1322',
#  '13220',
#  '1323',
#  '1327',
#  '13276',
#  '13282',
#  '13283',
#  '13291',
#  '13292',
#  '13310',
#  '13311',
#  '13318',
#  '13319',
#  '13320',
#  '13321',
#  '13322',
#  '13325',
#  '13328',
#  '13333',
#  '13334',
#  '13346',
#  '13352',
#  '13355',
#  '13357',
#  '13364',
#  '13369',
#  '13371',
#  '13384',
#  '13385',
#  '13387',
#  '13388',
#  '13389',
#  '1339',
#  '13390',
#  '13404',
#  '1341',
#  '13411',
#  '13413',
#  '13415',
#  '13422',
#  '1343',
#  '1344',
#  '1346',
#  '13469',
#  '1347',
#  '13470',
#  '13480',
#  '13481',
#  '13482',
#  '13483',
#  '13485',
#  '13486',
#  '13490',
#  '13493',
#  '13496',
#  '13497',
#  '13498',
#  '135',
#  '1350',
#  '13501',
#  '13520',
#  '13521',
#  '13526',
#  '13528',
#  '13529',
#  '1353',
#  '13556',
#  '13558',
#  '1356',
#  '13597',
#  '13600',
#  '13604',
#  '13614',
#  '13615',
#  '13616',
#  '13619',
#  '13620',
#  '13621',
#  '13622',
#  '13624',
#  '13625',
#  '13628',
#  '13635',
#  '13636',
#  '13641',
#  '13647',
#  '13649',
#  '13651',
#  '13653',
#  '13659',
#  '13664',
#  '13673',
#  '13675',
#  '13677',
#  '13680',
#  '13682',
#  '13683',
#  '13684',
#  '13702',
#  '13703',
#  '13704',
#  '13705',
#  '13711',
#  '13712',
#  '13713',
#  '13714',
#  '13717',
#  '1373',
#  '13740',
#  '13741',
#  '13749',
#  '1375',
#  '1376',
#  '1378',
#  '13801',
#  '13802',
#  '13813',
#  '13815',
#  '1383',
#  '13831',
#  '13832',
#  '13834',
#  '13837',
#  '13847',
#  '13859',
#  '1386',
#  '13862',
#  '13864',
#  '13929',
#  '13931',
#  '13932',
#  '13955',
#  '13966',
#  '13970',
#  '13971',
#  '13989',
#  '13990',
#  '13992',
#  '13995',
#  '13999',
#  '14',
#  '140',
#  '14003',
#  '14004',
#  '14007',
#  '14009',
#  '14020',
#  '1403',
#  '14033',
#  '14037',
#  '1404',
#  '1405',
#  '14051',
#  '14067',
#  '1407',
#  '14078',
#  '14079',
#  '1408',
#  '14089',
#  '14090',
#  '14093',
#  '14094',
#  '14096',
#  '141',
#  '14102',
#  '14123',
#  '14128',
#  '14130',
#  '14131',
#  '14132',
#  '14135',
#  '14149',
#  '14153',
#  '14154',
#  '14157',
#  '14159',
#  '14165',
#  '14170',
#  '14171',
#  '14174',
#  '14175',
#  '14176',
#  '14181',
#  '14182',
#  '142',
#  '1425',
#  '14265',
#  '1427',
#  '14282',
#  '14286',
#  '1430',
#  '14302',
#  '14308',
#  '14316',
#  '14317',
#  '14319',
#  '14324',
#  '14325',
#  '14337',
#  '14338',
#  '14339',
#  '14340',
#  '14344',
#  '14345',
#  '14346',
#  '14351',
#  '14353',
#  '14357',
#  '14358',
#  '1436',
#  '14369',
#  '14370',
#  '14371',
#  '14372',
#  '14373',
#  '14374',
#  '14376',
#  '14377',
#  '14379',
#  '14383',
#  '14384',
#  '14385',
#  '14403',
#  '14414',
#  '14419',
#  '14424',
#  '14430',
#  '14431',
#  '14485',
#  '14496',
#  '14497',
#  '14498',
#  '14499',
#  '14500',
#  '14502',
#  '14512',
#  '14534',
#  '14540',
#  '14541',
#  '14542',
#  '14543',
#  '14547',
#  '14550',
#  '14552',
#  '14558',
#  '14559',
#  '14560',
#  '14562',
#  '14599',
#  '14600',
#  '14606',
#  '14615',
#  '14616',
#  '14619',
#  '14620',
#  '14621',
#  '14627',
#  '14628',
#  '14638',
#  '14639',
#  '14647',
#  '14648',
#  '14652',
#  '14661',
#  '14662',
#  '14664',
#  '14667',
#  '14690',
#  '14691',
#  '14698',
#  '14707',
#  '14709',
#  '14710',
#  '14711',
#  '14746',
#  '14747',
#  '14763',
#  '14766',
#  '14767',
#  '14770',
#  '14771',
#  '14781',
#  '14807',
#  '14808',
#  '14809',
#  '14818',
#  '14834',
#  '14840',
#  '14841',
#  '14842',
#  '14843',
#  '14844',
#  '14845',
#  '14854',
#  '14864',
#  '14865',
#  '14868',
#  '14869',
#  '14870',
#  '14872',
#  '1488',
#  '14886',
#  '14894',
#  '1490',
#  '14924',
#  '1493',
#  '14932',
#  '14933',
#  '14952',
#  '14967',
#  '14969',
#  '1497',
#  '14970',
#  '14972',
#  '14976',
#  '1498',
#  '14982',
#  '14983',
#  '14985',
#  '1499',
#  '14990',
#  '14991',
#  '15003',
#  '15005',
#  '15006',
#  ...]

# %%
outpath = 'resources/physics/'
train, test = train_test_split(df, train_size = 0.8)
train.to_csv(os.path.join(outpath, 'train5.csv'), index=False)
test.to_csv(os.path.join(outpath, 'test5.csv'), index=False)

# %%
python3 embed.py \
       -dim 2 \
       -lr 0.3 \
       -epochs 100 \
       -negs 10 \
       -burnin 20 \
       -ndproc 4 \
       -manifold poincare \
       -dset resources/physics/train.csv \
       -checkpoint results/physics/result.pth \
       -batchsize 10 \
       -eval_each 1 \
       -sparse \
       -train_threads 2
       -sym

python3 embed.py \
       -dim 2 \
       -lr 0.3 \
       -epochs 200 \
       -negs 50 \
       -burnin 20 \
       -ndproc 4 \
       -manifold euclidean \
       -dset resources/physics/train.csv \
       -checkpoint results/physics/result_eu.pth \
       -batchsize 10 \
       -eval_each 1 \
       -sparse \
       -train_threads 2
       -sym

# %%
python3 link_pred.py \
       -dim 10 \
       -lr 0.3 \
       -epochs 100 \
       -negs 10 \
       -burnin 20 \
       -ndproc 4 \
       -manifold poincare \
       -dset resources/physics/data.csv \
       -batchsize 10 \
       -eval_each 20 \
       -sparse \
       -train_threads 2
       -sym

python3 link_pred.py \
       -dim 10 \
       -lr 0.3 \
       -epochs 100 \
       -negs 50 \
       -burnin 20 \
       -ndproc 4 \
       -manifold euclidean \
       -dset resources/physics/data.csv \
       -batchsize 10 \
       -eval_each 20 \
       -sparse \
       -train_threads 2 \
       -sym

# %%
def link_prob(d, r, t):
    return 1/(np.exp((d-r)/t)+1) #eq. 7 in paper


from hype.euclidean import EuclideanManifold
from hype.poincare import PoincareManifold

def predict_connections(obj, embedding, distfn, r=1, t=1):
    dists = 
    for i, node in obj:
        dists = distfn(embedding[None, i], embedding)
        dists[node] = 1e12
        print(dists)
        
    
from sklearn.metrics import average_precision_score
def calculate_ap(df, v): 
    nodes = sorted(df['id1'].unique())
    y_pred = []
    v_edge_to = df[df['id1' == v]]['id2']
    y_true = [1 if n in v_edge_to else 0 for n in nodes]
    return average_precision_score(y_true, y_pred)

# %%
chkpnt = torch.load('results/physics/result_0.pth', map_location='cpu')

embedding = chkpnt['embeddings']
obj = chkpnt['objects']

# %%
obj
# Out:
# [3466,
#  937,
#  5233,
#  8579,
#  15931,
#  17038,
#  19607,
#  10310,
#  1854,
#  4583,
#  9572,
#  10841,
#  13056,
#  14982,
#  16310,
#  23855,
#  24372,
#  24814,
#  5052,
#  899,
#  1796,
#  2287,
#  3096,
#  3386,
#  4472,
#  5346,
#  5740,
#  9124,
#  10235,
#  10427,
#  16148,
#  16741,
#  18235,
#  18549,
#  19297,
#  20511,
#  20595,
#  24371,
#  24559,
#  25102,
#  25271,
#  25396,
#  1658,
#  4822,
#  6864,
#  7689,
#  7926,
#  10268,
#  12971,
#  15159,
#  18600,
#  20421,
#  20886,
#  21048,
#  22393,
#  23186,
#  23214,
#  23298,
#  23945,
#  24939,
#  19640,
#  339,
#  3731,
#  4743,
#  5407,
#  6610,
#  6700,
#  8045,
#  9099,
#  9639,
#  9785,
#  12141,
#  15184,
#  18719,
#  19870,
#  23576,
#  23577,
#  23649,
#  24293,
#  25201,
#  10243,
#  8049,
#  8053,
#  8517,
#  11964,
#  15538,
#  16694,
#  18648,
#  19423,
#  21012,
#  22457,
#  22691,
#  23452,
#  16174,
#  16470,
#  17822,
#  14265,
#  2485,
#  3173,
#  3441,
#  3853,
#  3927,
#  3939,
#  5107,
#  5218,
#  5230,
#  6030,
#  7504,
#  7601,
#  8718,
#  9522,
#  12498,
#  12691,
#  15251,
#  16020,
#  17156,
#  19059,
#  19525,
#  20122,
#  20432,
#  21866,
#  22074,
#  23721,
#  19738,
#  8916,
#  13556,
#  14485,
#  8612,
#  615,
#  743,
#  2076,
#  4515,
#  5773,
#  9482,
#  11604,
#  14004,
#  15003,
#  15552,
#  15814,
#  16083,
#  17932,
#  20001,
#  20100,
#  23481,
#  10822,
#  16258,
#  1356,
#  1727,
#  2752,
#  4125,
#  6667,
#  6825,
#  10351,
#  11082,
#  14123,
#  16676,
#  21194,
#  10039,
#  10912,
#  14534,
#  17268,
#  19783,
#  21705,
#  22836,
#  2710,
#  106,
#  2959,
#  3677,
#  4708,
#  5172,
#  5541,
#  5794,
#  6575,
#  8458,
#  10601,
#  13026,
#  13205,
#  13659,
#  13989,
#  14007,
#  14009,
#  14599,
#  15301,
#  20934,
#  21543,
#  22184,
#  23647,
#  23708,
#  25916,
#  26023,
#  26051,
#  26100,
#  18757,
#  214,
#  5435,
#  6512,
#  10590,
#  23559,
#  62,
#  1765,
#  3032,
#  5302,
#  7383,
#  7442,
#  7768,
#  17266,
#  22415,
#  10794,
#  7050,
#  25850,
#  10113,
#  10657,
#  12130,
#  4846,
#  676,
#  824,
#  2133,
#  4748,
#  10549,
#  12928,
#  13220,
#  17330,
#  17439,
#  20850,
#  22779,
#  23382,
#  24029,
#  11785,
#  14419,
#  18487,
#  570,
#  773,
#  1653,
#  2212,
#  2952,
#  3372,
#  4046,
#  4164,
#  4511,
#  4513,
#  5262,
#  6179,
#  7956,
#  8879,
#  11241,
#  11472,
#  12365,
#  12678,
#  12781,
#  12851,
#  14540,
#  14807,
#  15659,
#  15784,
#  16159,
#  17655,
#  17692,
#  19961,
#  20108,
#  20562,
#  20635,
#  21281,
#  21508,
#  21847,
#  22798,
#  22887,
#  24955,
#  25346,
#  25758,
#  624,
#  934,
#  2654,
#  5579,
#  9755,
#  16032,
#  17331,
#  20644,
#  22497,
#  23293,
#  23387,
#  23907,
#  24924,
#  25080,
#  12422,
#  1339,
#  15580,
#  16393,
#  20478,
#  20956,
#  3164,
#  3890,
#  5621,
#  8824,
#  11613,
#  12860,
#  18182,
#  24696,
#  7899,
#  8067,
#  11132,
#  12980,
#  13364,
#  14969,
#  16389,
#  18109,
#  18365,
#  23038,
#  24845,
#  25379,
#  13740,
#  4550,
#  4702,
#  7264,
#  13096,
#  19489,
#  19527,
#  22476,
#  25006,
#  25486,
#  26,
#  1407,
#  1488,
#  8219,
#  10762,
#  11801,
#  12665,
#  12688,
#  13142,
#  14128,
#  15108,
#  15321,
#  20647,
#  20827,
#  20879,
#  23614,
#  3909,
#  17979,
#  3872,
#  5109,
#  7533,
#  11175,
#  12409,
#  20101,
#  23096,
#  8862,
#  78,
#  4877,
#  7459,
#  8254,
#  12155,
#  22598,
#  24932,
#  888,
#  1520,
#  6468,
#  6627,
#  7350,
#  7712,
#  10711,
#  14102,
#  18517,
#  18676,
#  23351,
#  23689,
#  24114,
#  2465,
#  2592,
#  5055,
#  5993,
#  9265,
#  19890,
#  21560,
#  17309,
#  24833,
#  543,
#  1958,
#  2193,
#  3917,
#  6858,
#  8148,
#  12478,
#  15366,
#  18125,
#  19675,
#  21806,
#  26196,
#  10115,
#  10134,
#  23916,
#  7893,
#  5510,
#  9360,
#  12334,
#  12627,
#  18051,
#  593,
#  13385,
#  16778,
#  19578,
#  12386,
#  8978,
#  9017,
#  15170,
#  15455,
#  16589,
#  2255,
#  3056,
#  6158,
#  7307,
#  7324,
#  8365,
#  9023,
#  12324,
#  12472,
#  13831,
#  14746,
#  16128,
#  18875,
#  19900,
#  20806,
#  21944,
#  21968,
#  23302,
#  23665,
#  23758,
#  12045,
#  12287,
#  14181,
#  17075,
#  21613,
#  7510,
#  8851,
#  197,
#  1343,
#  2991,
#  15416,
#  18088,
#  25286,
#  1254,
#  3420,
#  10130,
#  2250,
#  7717,
#  7985,
#  11015,
#  12085,
#  12306,
#  13714,
#  14767,
#  16056,
#  16994,
#  17414,
#  18971,
#  19216,
#  20534,
#  21776,
#  21860,
#  25205,
#  178,
#  1248,
#  1403,
#  2368,
#  2420,
#  7007,
#  16210,
#  20641,
#  24762,
#  2307,
#  6934,
#  22423,
#  3937,
#  45,
#  46,
#  231,
#  345,
#  1186,
#  1841,
#  1997,
#  2404,
#  2450,
#  2741,
#  2980,
#  3409,
#  5134,
#  5578,
#  6774,
#  8503,
#  9341,
#  12496,
#  12503,
#  13060,
#  18208,
#  18543,
#  18866,
#  18894,
#  22421,
#  22937,
#  23363,
#  23628,
#  25053,
#  25251,
#  1234,
#  2982,
#  4036,
#  4115,
#  6830,
#  12938,
#  19215,
#  22726,
#  22834,
#  22966,
#  23511,
#  25528,
#  25836,
#  13597,
#  14376,
#  16611,
#  8710,
#  2846,
#  5555,
#  5564,
#  5787,
#  9721,
#  10158,
#  10942,
#  13614,
#  21075,
#  21316,
#  22900,
#  23770,
#  25143,
#  25601,
#  25980,
#  17394,
#  18924,
#  3113,
#  8312,
#  10765,
#  11621,
#  17538,
#  25978,
#  5674,
#  26194,
#  375,
#  1172,
#  12733,
#  7188,
#  896,
#  1508,
#  6815,
#  7209,
#  8279,
#  13008,
#  18605,
#  21158,
#  4632,
#  7844,
#  13411,
#  14512,
#  16594,
#  16726,
#  16876,
#  19954,
#  19992,
#  20391,
#  20774,
#  23403,
#  4870,
#  8282,
#  22046,
#  5175,
#  2449,
#  4766,
#  3561,
#  4868,
#  8352,
#  10456,
#  15365,
#  16931,
#  8157,
#  2120,
#  7713,
#  19052,
#  8302,
#  16484,
#  17778,
#  2556,
#  21699,
#  8701,
#  523,
#  5464,
#  7774,
#  17379,
#  23385,
#  26170,
#  1310,
#  2922,
#  3651,
#  6891,
#  10162,
#  13174,
#  14864,
#  17536,
#  23153,
#  24340,
#  11102,
#  18037,
#  18592,
#  22765,
#  6838,
#  25220,
#  2949,
#  4180,
#  10055,
#  1832,
#  7014,
#  9397,
#  14344,
#  14385,
#  21379,
#  4416,
#  24163,
#  2620,
#  3679,
#  4364,
#  13955,
#  14003,
#  19495,
#  23967,
#  1116,
#  15235,
#  18222,
#  21287,
#  4624,
#  5355,
#  6863,
#  12606,
#  12968,
#  15770,
#  21322,
#  22265,
#  22336,
#  23099,
#  23880,
#  25111,
#  4319,
#  22023,
#  14337,
#  10763,
#  11121,
#  11194,
#  15799,
#  16511,
#  16945,
#  21157,
#  2326,
#  5849,
#  10253,
#  13190,
#  14325,
#  18174,
#  17850,
#  20620,
#  21432,
#  21707,
#  12380,
#  3197,
#  6160,
#  8589,
#  14638,
#  14924,
#  15972,
#  18940,
#  19475,
#  20207,
#  22790,
#  24001,
#  25228,
#  9710,
#  19159,
#  3345,
#  3430,
#  5995,
#  7999,
#  8047,
#  8178,
#  8868,
#  15144,
#  19806,
#  23304,
#  24431,
#  11077,
#  10211,
#  14972,
#  15300,
#  17158,
#  17162,
#  17403,
#  20149,
#  20519,
#  21389,
#  22951,
#  23912,
#  25589,
#  23918,
#  6895,
#  3076,
#  7444,
#  8972,
#  17308,
#  20574,
#  21629,
#  245,
#  4983,
#  15912,
#  16976,
#  19974,
#  22245,
#  13480,
#  8708,
#  23776,
#  4975,
#  5809,
#  11148,
#  12587,
#  20303,
#  4451,
#  9983,
#  15205,
#  15666,
#  15667,
#  19093,
#  21031,
#  5840,
#  8614,
#  13847,
#  5143,
#  9735,
#  17396,
#  26138,
#  4700,
#  5606,
#  1386,
#  1738,
#  2566,
#  2720,
#  9870,
#  16779,
#  24475,
#  25931,
#  1817,
#  3725,
#  5366,
#  15911,
#  1044,
#  9800,
#  18001,
#  22177,
#  25480,
#  1425,
#  2501,
#  2823,
#  5136,
#  7105,
#  7317,
#  9127,
#  14615,
#  17089,
#  19454,
#  22644,
#  22758,
#  23841,
#  24199,
#  3207,
#  7125,
#  20683,
#  25419,
#  2591,
#  8932,
#  9188,
#  13713,
#  19179,
#  14818,
#  26190,
#  3839,
#  12637,
#  16674,
#  7042,
#  9269,
#  11661,
#  21994,
#  9943,
#  15614,
#  16368,
#  17172,
#  21407,
#  8715,
#  10096,
#  21142,
#  21167,
#  25388,
#  13621,
#  284,
#  6427,
#  16835,
#  18677,
#  21696,
#  25940,
#  9485,
#  10435,
#  14698,
#  16123,
#  21823,
#  811,
#  9964,
#  11919,
#  15123,
#  17021,
#  19517,
#  22989,
#  23485,
#  8069,
#  2127,
#  11712,
#  10871,
#  15829,
#  17670,
#  18286,
#  19724,
#  22876,
#  3412,
#  17207,
#  894,
#  4814,
#  5441,
#  5717,
#  9075,
#  10623,
#  11223,
#  11491,
#  12659,
#  13276,
#  14351,
#  19807,
#  21665,
#  22734,
#  22778,
#  23246,
#  25698,
#  7615,
#  5934,
#  12806,
#  18612,
#  1620,
#  3310,
#  3922,
#  9133,
#  9895,
#  9907,
#  11791,
#  17626,
#  18457,
#  19131,
#  19997,
#  21491,
#  22791,
#  23637,
#  25158,
#  25316,
#  17228,
#  352,
#  3996,
#  10555,
#  15850,
#  19101,
#  20533,
#  21943,
#  22603,
#  23513,
#  25034,
#  1280,
#  5851,
#  16921,
#  21646,
#  17559,
#  1674,
#  3323,
#  8680,
#  9184,
#  19204,
#  19657,
#  20373,
#  23204,
#  19206,
#  13813,
#  409,
#  2474,
#  4241,
#  6746,
#  10476,
#  16568,
#  21771,
#  2081,
#  3593,
#  9829,
#  12212,
#  13528,
#  14628,
#  22574,
#  25872,
#  1545,
#  2202,
#  5266,
#  15206,
#  17233,
#  21317,
#  24271,
#  8547,
#  10791,
#  10919,
#  11275,
#  15600,
#  15608,
#  24568,
#  25996,
#  26098,
#  1059,
#  6154,
#  7725,
#  11125,
#  13705,
#  16039,
#  17821,
#  18540,
#  20536,
#  23529,
#  10588,
#  3916,
#  4952,
#  5352,
#  5729,
#  13801,
#  15311,
#  21754,
#  23134,
#  24614,
#  4493,
#  14627,
#  23720,
#  930,
#  3946,
#  4760,
#  17189,
#  10463,
#  10526,
#  11788,
#  17746,
#  18189,
#  19107,
#  21438,
#  22611,
#  26038,
#  4195,
#  7069,
#  9098,
#  21723,
#  24587,
#  7895,
#  9773,
#  11863,
#  12110,
#  1000,
#  1149,
#  1694,
#  2115,
#  4575,
#  5605,
#  6288,
#  12070,
#  13469,
#  16101,
#  20716,
#  23107,
#  25402,
#  25948,
#  6963,
#  8374,
#  17465,
#  23939,
#  3006,
#  3630,
#  5901,
#  5953,
#  7911,
#  8730,
#  10406,
#  12874,
#  13177,
#  24885,
#  18008,
#  ...]

# %%
embedding[None,17038]
# Out:
# --------------------------------------------------------------------------
# IndexError                               Traceback (most recent call last)
# <ipython-input-64-74c346eebca9> in <module>
# ----> 1 embedding[None,17038]
#
# IndexError: index 17038 is out of bounds for dimension 1 with size 5198

# %%
len(obj)
# Out:
# 5198

# %%
embedding.shape
# Out:
# torch.Size([5198, 10])

# %%
embedding[None,1124].shape
# Out:
# torch.Size([1, 10])

# %%
from hype.poincare import PoincareManifold

# %%
predict_connections(obj, embedding, PoincareManifold().distance)
# Out:
# tensor([6.7818, 7.5728, 7.1027,  ..., 8.4074, 8.3837, 8.3637],
#        dtype=torch.float64)
# tensor([6.8611, 7.6316, 7.1831,  ..., 8.6717, 8.6480, 8.6280],
#        dtype=torch.float64)
# --------------------------------------------------------------------------
# IndexError                               Traceback (most recent call last)
# <ipython-input-62-6f4b90c5030e> in <module>
# ----> 1 predict_connections(obj, embedding, PoincareManifold().distance)
#
# <ipython-input-61-caab0309a020> in predict_connections(obj, embedding, distfn, r, t)
#       9
#      10     for node in obj:
# ---> 11         dists = distfn(embedding[None, node], embedding)
#      12         dists[node] = 1e12
#      13         print(dists)
#
# IndexError: index 5233 is out of bounds for dimension 1 with size 5198

# %%
from hype.graph import load_adjacency_matrix, load_edge_list, eval_reconstruction

# %%
def read_gml(inpath, outpath, attribute_name='value'):

    G = nx.read_gml(inpath)
    G = G.to_undirected()
    # get labels
    label_dic = nx.get_node_attributes(G, attribute_name)

    df = pandas.DataFrame(G.edges(), columns=['id1', 'id2'])
    df['weight'] = 1

    df.to_csv(os.path.join(outpath, 'data.csv'), index=False)
    with open(os.path.join(outpath, 'labels.json'), 'w') as f:
        json.dump(label_dic, f)

    return df, label_dic

# %%
read_gml("resources/polblogs/polblogs.gml", "resources/polblogs")

# %%
python3 embed.py \
       -dim 2 \
       -lr 0.3 \
       -epochs 200 \
       -negs 10 \
       -burnin 20 \
       -ndproc 4 \
       -manifold poincare \
       -dset resources/polbooks/data.csv \
       -checkpoint results/polbooks/result.pth \
       -batchsize 10 \
       -eval_each 1 \
       -sparse \
       -train_threads 2

python3 embed.py \
       -dim 2 \
       -lr 0.3 \
       -epochs 200 \
       -negs 50 \
       -burnin 20 \
       -ndproc 4 \
       -manifold euclidean \
       -dset resources/polbooks/data.csv \
       -checkpoint results/polbooks/result_eu.pth \
       -batchsize 10 \
       -eval_each 1 \
       -sparse \
       -train_threads 2
# Out:
#   File "<ipython-input-69-6ea573ec5ff0>", line 1
#     python3 embed.py \
#                 ^
# SyntaxError: invalid syntax

# %%
with open(os.path.join('resources/polblogs/labels.json'), 'r') as f:
    labels_dic = json.load(f)
data = pandas.read_csv("resources/polblogs/data.csv")

# %%
chkpnt = torch.load('results/polblogs/result.pth', map_location='cpu')

lt = chkpnt['embeddings']
obj = chkpnt['objects']
epk = chkpnt['epoch']
labels = [labels_dic[o] for o in obj]
lt_np = lt.numpy()
df = pandas.DataFrame(lt_np, columns=['x', 'y'])
df['label'] = labels
df['name'] = obj

fig = plt.figure(figsize=(8, 8))
ax = sns.scatterplot(x="x", y="y", hue="label", data=df)
ax.set_aspect('equal')
ax.set_title('Polblogs - Poincare - Epoch %s'%epk)

'''
index = {obj[i]:i for i in range(len(obj))}
ct = 0
for i, edge in data.iterrows():
    n1 = edge['id1']
    c1 = lt_np[index[n1]]
    n2 = edge['id2']
    c2 = lt_np[index[n2]]
    if np.linalg.norm(c1-c2)>1:
        ct += 1
        plt.plot([c1[0],c2[0]], [c1[1],c2[1]], 'k-', linewidth=0.5, alpha=0.2)
print(ct)

middle = df[df.apply(lambda x: x['x']**2+ x['y']**2 <0.4, axis=1)]
for i, point in middle.iterrows():
    ax.text(point['x']+.02, point['y'], str(point['name']))
'''
# Out:
# "\nindex = {obj[i]:i for i in range(len(obj))}\nct = 0\nfor i, edge in data.iterrows():\n    n1 = edge['id1']\n    c1 = lt_np[index[n1]]\n    n2 = edge['id2']\n    c2 = lt_np[index[n2]]\n    if np.linalg.norm(c1-c2)>1:\n        ct += 1\n        plt.plot([c1[0],c2[0]], [c1[1],c2[1]], 'k-', linewidth=0.5, alpha=0.2)\nprint(ct)\n\nmiddle = df[df.apply(lambda x: x['x']**2+ x['y']**2 <0.4, axis=1)]\nfor i, point in middle.iterrows():\n    ax.text(point['x']+.02, point['y'], str(point['name']))\n"

# %%
chkpnt = torch.load('results/polblogs/result.pth', map_location='cpu')

lt = chkpnt['embeddings']
obj = chkpnt["objects"]
epk = chkpnt['epoch']
labels = [labels_dic[o] for o in obj]
lt_numpy = lt.numpy()
df = pandas.DataFrame(lt_numpy, columns=['x', 'y'])
df['label'] = labels
df['name'] = obj

fig = plt.figure(figsize=(8, 8))
ax = sns.scatterplot(x="x", y="y", hue="label", data=df)
ax.set_aspect('equal')
ax.set_title('Polblogs - Poincare - Epoch %s'%epk)

# %%
data.shape
# Out:
# (16783, 3)

# %%
chkpnt = torch.load('results/polblogs/result_eu.pth', map_location='cpu')

lt = chkpnt['embeddings']
obj = chkpnt["objects"]
epk = chkpnt['epoch']
labels = [labels_dic[o] for o in obj]
lt_numpy = lt.numpy()
df = pandas.DataFrame(lt_numpy, columns=['x', 'y'])
df['label'] = labels
df['name'] = obj

fig = plt.figure(figsize=(8, 8))
ax = sns.scatterplot(x="x", y="y", hue="label", data=df)
ax.set_aspect('equal')
ax.set_title('Polblogs - Euclidian - Epoch %s'%epk)
# Out:
# "\nmiddle = df[df.apply(lambda x: x['x']**2+ x['y']**2 <0.4, axis=1)]\nfor i, point in middle.iterrows():\n    ax.text(point['x']+.02, point['y'], str(point['name']))\n"

# %%
data, labels_dic = read_gml("resources/polbooks/polbooks.gml", "resources/polbooks")

# %%
def exp():

# %%
data, labels_dic = read_gml("resources/polbooks/polbooks.gml", 
                                "resources/polbooks")
    
    
chkpnt = torch.load('results/polbooks/result.pth', map_location='cpu')

lt = chkpnt['embeddings']
obj = chkpnt["objects"]
epk = chkpnt['epoch']
labels = [labels_dic[o] for o in obj]
lt_np = lt.numpy()
df = pandas.DataFrame(lt_np, columns=['x', 'y'])
df['label'] = labels
df['name'] = obj

fig = plt.figure(figsize=(8, 8))
ax = sns.scatterplot(x="x", y="y", hue="label", data=df)
ax.set_aspect('equal')
ax.set_title('polbooks - Poincare - Epoch %s'%epk)

index = {obj[i]:i for i in range(len(obj))}
ct = 0
for i, edge in data.iterrows():
    n1 = edge['id1']
    c1 = lt_np[index[n1]]
    n2 = edge['id2']
    c2 = lt_np[index[n2]]
    #if np.linalg.norm(c1-c2)>0.1:
    #    ct += 1
    plt.plot([c1[0],c2[0]], [c1[1],c2[1]], 'k-', linewidth=0.5, alpha=0.2)
print(ct)
# Out:
# 0

# %%
chkpnt = torch.load('results/polbooks/result.pth', map_location='cpu')

lt = chkpnt['embeddings']
obj = chkpnt["objects"]
epk = chkpnt['epoch']
labels = [labels_dic[o] for o in obj]
lt_numpy = lt.numpy()
df = pandas.DataFrame(lt_numpy, columns=['x', 'y'])
df['label'] = labels
df['name'] = obj

fig = plt.figure(figsize=(8, 8))
ax = sns.scatterplot(x="x", y="y", hue="label", data=df)
ax.set_aspect('equal')
ax.set_title('polbooks - Poincare - Epoch %s'%epk)
# Out:
# Text(0.5, 1.0, 'polbooks - Poincare - Epoch 199')

# %%
chkpnt = torch.load('results/polbooks/result_eu.pth', map_location='cpu')

lt = chkpnt['embeddings']
obj = chkpnt["objects"]
epk = chkpnt['epoch']
labels = [labels_dic[o] for o in obj]
lt_np= lt.numpy()
df = pandas.DataFrame(lt_np, columns=['x', 'y'])
df['label'] = labels
df['name'] = obj

fig = plt.figure(figsize=(8, 8))
ax = sns.scatterplot(x="x", y="y", hue="label", data=df)
ax.set_aspect('equal')
ax.set_title('polbooks - Euclidian - Epoch %s'%epk)
'''
middle = df[df.apply(lambda x: x['x']**2+ x['y']**2 <0.4, axis=1)]
for i, point in middle.iterrows():
    ax.text(point['x']+.02, point['y'], str(point['name']))
'''

index = {obj[i]:i for i in range(len(obj))}
ct = 0
for i, edge in data.iterrows():
    n1 = edge['id1']
    c1 = lt_np[index[n1]]
    n2 = edge['id2']
    c2 = lt_np[index[n2]]
    #if np.linalg.norm(c1-c2)>0.1:
    #    ct += 1
    plt.plot([c1[0],c2[0]], [c1[1],c2[1]], 'k-', linewidth=0.5, alpha=0.2)
print(ct)
# Out:
# 0

# %%
labels = ["Case_Based", "Genetic_Algorithms", "Neural_Networks", 
    "Probabilistic_Methods", "Reinforcement_Learning",
    "Rule_Learning","Theory"]

# %%
def read_cora():
    links = []
    with open("resources/cora/cora.cites",'r') as f:
        line = f.readline()
        cnt = 1
        while line:
            links.append((line.strip().split("\t")))
            line = f.readline()
            cnt += 1
    print(cnt)
    df = pandas.DataFrame(links, columns=['id1', 'id2'])
    rev = df.copy().rename(columns={'id1' : 'id2', 'id2' : 'id1'})
    df = pandas.concat([df, rev])
    df['weight'] = 1
    df.to_csv(os.path.join("resources/cora", 'data.csv'), index=False)
    
    label_dic = {}

    with open("resources/cora/cora.content",'r') as f:
        line = f.readline()
        while line:
            info = line.strip().split("\t")
            label_dic[info[0]] = info[-1]
            line = f.readline()


    with open(os.path.join("resources/cora", 'labels.json'), 'w') as f:
        json.dump(label_dic, f)

    return df, label_dic

# %%
cora_df, cora_label = read_cora()
# Out:
# 5430
# /home/ss/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   del sys.path[0]

# %%
python3 embed.py \
       -dim 2 \
       -lr 0.3 \
       -epochs 200 \
       -negs 50 \
       -burnin 20 \
       -ndproc 4 \
       -manifold poincare \
       -dset resources/cora/data.csv \
       -checkpoint results/cora/result.pth \
       -batchsize 10 \
       -eval_each 1 \
       -sparse \
       -train_threads 2

python3 embed.py \
       -dim 2 \
       -lr 0.3 \
       -epochs 200 \
       -negs 50 \
       -burnin 20 \
       -ndproc 4 \
       -manifold euclidean \
       -dset resources/cora/data.csv \
       -checkpoint results/cora/result_eu.pth \
       -batchsize 10 \
       -eval_each 1 \
       -sparse \
       -train_threads 2

# %%
list(set(labels))
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
df.label.unique()
# Out:
# array([1, 2, 6, 4, 0, 3, 5])

# %%
len(obj)
# Out:
# 2708

# %%
chkpnt = torch.load('results/cora/result.pth', map_location='cpu')

lt = chkpnt['embeddings']
obj = chkpnt["objects"]
epk = chkpnt['epoch']
labels = [cora_label[str(o)] for o in obj]
lt_numpy = lt.numpy()
df = pandas.DataFrame(lt_numpy, columns=['x', 'y'])
df['label'] = labels
df['name'] = obj

fig = plt.figure(figsize=(10, 10))
ax = sns.scatterplot(x="x", y="y", hue="label", data=df)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_aspect('equal')
ax.set_title('Cora - Poincare - Epoch %s'%epk)
# Out:
# Text(0.5, 1.0, 'Cora - Poincare - Epoch 198')

# %%
chkpnt = torch.load('results/cora/result_eu.pth', map_location='cpu')

lt = chkpnt['embeddings']
obj = chkpnt["objects"]
epk = chkpnt['epoch']
labels = [cora_label[str(o)] for o in obj]
lt_np= lt.numpy()
df = pandas.DataFrame(lt_np, columns=['x', 'y'])
df['label'] = labels
df['name'] = obj

fig = plt.figure(figsize=(8, 8))
ax = sns.scatterplot(x="x", y="y", hue="label", data=df)
ax.set_aspect('equal')
ax.set_title('polbooks - Euclidian - Epoch %s'%epk)
'''
middle = df[df.apply(lambda x: x['x']**2+ x['y']**2 <0.4, axis=1)]
for i, point in middle.iterrows():
    ax.text(point['x']+.02, point['y'], str(point['name']))
'''

index = {obj[i]:i for i in range(len(obj))}
ct = 0
for i, edge in data.iterrows():
    n1 = edge['id1']
    c1 = lt_np[index[n1]]
    n2 = edge['id2']
    c2 = lt_np[index[n2]]
    #if np.linalg.norm(c1-c2)>0.1:
    #    ct += 1
    plt.plot([c1[0],c2[0]], [c1[1],c2[1]], 'k-', linewidth=0.5, alpha=0.2)
print(ct)
# Out:
# --------------------------------------------------------------------------
# KeyError                                 Traceback (most recent call last)
# <ipython-input-214-640a76377a6b> in <module>
#      24 for i, edge in data.iterrows():
#      25     n1 = edge['id1']
# ---> 26     c1 = lt_np[index[n1]]
#      27     n2 = edge['id2']
#      28     c2 = lt_np[index[n2]]
#
# KeyError: '100monkeystyping.com'

# %%
chkpnt = torch.load('results/mammals.pth', map_location='cpu')
lt = chkpnt['embeddings']

# %%
lt.shape
# Out:
# torch.Size([1180, 5])

# %%
lt_np = lt.numpy()

# %%
lt_2d = lt_np[:,:2]

# %%
print(lt_2d[0])
# Out:
# [-0.47410328  0.69495815]

# %%
plt.scatter(lt_2d[:,0], lt_2d[:,1])

# %%
chkpnt = torch.load('results/2d/mammals.pth', map_location='cpu')
lt = chkpnt['embeddings']

# %%
chkpnt.keys()
# Out:
# dict_keys(['conf', 'objects', 'model', 'embeddings', 'epoch', 'manifold'])

# %%
chkpnt["objects"]
# Out:
# ['rhodesian_man.n.01',
#  'primate.n.02',
#  'stoat.n.01',
#  'placental.n.01',
#  'hind.n.02',
#  'deer.n.01',
#  'fissipedia.n.01',
#  'mammal.n.01',
#  'virginia_deer.n.01',
#  'ruminant.n.01',
#  'bottle-nosed_whale.n.01',
#  'toothed_whale.n.01',
#  'bushbuck.n.01',
#  'western_lowland_gorilla.n.01',
#  'leopard.n.02',
#  'big_cat.n.01',
#  'western_big-eared_bat.n.01',
#  'carnivorous_bat.n.01',
#  'lionet.n.01',
#  'feline.n.01',
#  'stag.n.02',
#  'buck.n.05',
#  'fawn.n.02',
#  'manx.n.02',
#  'domestic_cat.n.01',
#  'australopithecus_boisei.n.01',
#  'rat_terrier.n.01',
#  'northern_flying_squirrel.n.01',
#  'rodent.n.01',
#  'irish_wolfhound.n.01',
#  'hunting_dog.n.01',
#  'eared_seal.n.01',
#  'aquatic_mammal.n.01',
#  'giant_eland.n.01',
#  'mouse-eared_bat.n.01',
#  'woodland_caribou.n.01',
#  'galloway.n.02',
#  'bovine.n.01',
#  'mandrill.n.01',
#  'eland.n.01',
#  'gopher.n.04',
#  'bezoar_goat.n.01',
#  'welsh.n.03',
#  'sporting_dog.n.01',
#  'canine.n.02',
#  'old_world_buffalo.n.01',
#  'mountain_chinchilla.n.01',
#  'wild_dog.n.01',
#  'common_raccoon.n.01',
#  'procyonid.n.01',
#  'hooded_skunk.n.01',
#  'musteline_mammal.n.01',
#  'even-toed_ungulate.n.01',
#  'striped_muishond.n.01',
#  'muishond.n.01',
#  'fur_seal.n.02',
#  'seal.n.09',
#  'thoroughbred.n.02',
#  'ungulate.n.01',
#  'wild_horse.n.01',
#  'mouse.n.01',
#  'plains_pocket_mouse.n.01',
#  'english_foxhound.n.01',
#  'dog.n.01',
#  'yellow-throated_marten.n.01',
#  'carnivore.n.01',
#  'affenpinscher.n.01',
#  'cattalo.n.01',
#  'bovid.n.01',
#  'affirmed.n.01',
#  'indian_buffalo.n.01',
#  'brown_lemming.n.01',
#  'beef.n.01',
#  'australopithecus_afarensis.n.01',
#  'jaguar.n.01',
#  'charolais.n.01',
#  'standard_poodle.n.01',
#  'eohippus.n.01',
#  'odd-toed_ungulate.n.01',
#  'pichiciago.n.01',
#  'armadillo.n.01',
#  'clydesdale_terrier.n.01',
#  'indian_rhinoceros.n.01',
#  'rhinoceros.n.01',
#  'baboon.n.01',
#  'coach_horse.n.01',
#  'spitz.n.01',
#  'alaskan_brown_bear.n.01',
#  'ground_squirrel.n.02',
#  'striped_hyena.n.01',
#  'sennenhunde.n.01',
#  'bucking_bronco.n.01',
#  'pony.n.01',
#  'steller_sea_lion.n.01',
#  'barren_ground_caribou.n.01',
#  'hereford.n.01',
#  'toy_dog.n.01',
#  'guenon.n.01',
#  'hairy-legged_vampire_bat.n.01',
#  'vampire_bat.n.01',
#  'taguan.n.01',
#  'sei_whale.n.01',
#  'rorqual.n.01',
#  'hyena.n.01',
#  'whippet.n.01',
#  'angora.n.04',
#  'macrotus.n.01',
#  'bat.n.01',
#  'norfolk_terrier.n.01',
#  'antelope_squirrel.n.01',
#  'squirrel.n.01',
#  'water_buffalo.n.01',
#  'bull_mastiff.n.01',
#  'porcupine.n.01',
#  'timber_wolf.n.01',
#  'tiger_cat.n.02',
#  'kanchil.n.01',
#  'aberdeen_angus.n.01',
#  'lynx.n.02',
#  'wildcat.n.03',
#  'eurasian_otter.n.01',
#  'gomphothere.n.01',
#  'collared_pika.n.01',
#  'marten.n.01',
#  'belgian_sheepdog.n.01',
#  'shepherd_dog.n.01',
#  'boston_bull.n.01',
#  'hack.n.06',
#  'equine.n.01',
#  'german_shepherd.n.01',
#  'miniature_poodle.n.01',
#  'mountain_zebra.n.01',
#  'ord_kangaroo_rat.n.01',
#  'rat.n.01',
#  'jackrabbit.n.01',
#  'hare.n.01',
#  'warthog.n.01',
#  'yak.n.02',
#  'bearded_seal.n.01',
#  'cotton_mouse.n.01',
#  'kangaroo_mouse.n.01',
#  'wire-haired_fox_terrier.n.01',
#  'harnessed_antelope.n.01',
#  'large_poodle.n.01',
#  'banded_palm_civet.n.01',
#  'red_squirrel.n.02',
#  'airedale.n.01',
#  'exmoor.n.02',
#  'pony.n.05',
#  'water_dog.n.02',
#  'brown_hyena.n.01',
#  'giant_panda.n.01',
#  'aegyptopithecus.n.01',
#  'weasel.n.02',
#  'two-toed_sloth.n.02',
#  'sloth.n.02',
#  'springer.n.02',
#  'cattle.n.01',
#  'mara.n.02',
#  'staffordshire_bullterrier.n.01',
#  'cactus_mouse.n.01',
#  'wapiti.n.01',
#  'brown_bear.n.01',
#  'bear.n.01',
#  'mesohippus.n.01',
#  'maltese.n.03',
#  'kuvasz.n.01',
#  'nyala.n.02',
#  'packrat.n.02',
#  'wood_rat.n.01',
#  'homo_habilis.n.01',
#  'hominid.n.01',
#  'brocket.n.01',
#  'domestic_ass.n.01',
#  'entlebucher.n.01',
#  'palm_cat.n.01',
#  'baleen_whale.n.01',
#  'tiglon.n.01',
#  'housedog.n.01',
#  'mastodon.n.01',
#  'proboscidean.n.01',
#  'pygmy_chimpanzee.n.01',
#  'anthropoid_ape.n.01',
#  'guernsey.n.02',
#  'dairy_cattle.n.01',
#  'longtail_weasel.n.01',
#  'collie.n.01',
#  'abyssinian.n.01',
#  'komondor.n.01',
#  'seattle_slew.n.01',
#  'kaffir_cat.n.01',
#  'takin.n.01',
#  'mountain_nyala.n.01',
#  'basset.n.01',
#  'persian_cat.n.01',
#  'asiatic_flying_squirrel.n.01',
#  'cocker_spaniel.n.01',
#  'lechwe.n.01',
#  'dark_horse.n.02',
#  'rottweiler.n.01',
#  'briard.n.01',
#  'american_staffordshire_terrier.n.01',
#  'nilgai.n.01',
#  'homo.n.02',
#  'courser.n.03',
#  'mudder.n.01',
#  'naked_mole_rat.n.01',
#  'fossorial_mammal.n.01',
#  'cynopterus_sphinx.n.01',
#  'fruit_bat.n.01',
#  'standard_schnauzer.n.01',
#  "przewalski's_horse.n.01",
#  'forest_goat.n.01',
#  'steeplechaser.n.01',
#  'horse.n.01',
#  'cat.n.01',
#  'grey.n.07',
#  'old_english_sheepdog.n.01',
#  'working_dog.n.01',
#  'griffon.n.02',
#  'mexican_hairless.n.01',
#  'dugong.n.01',
#  'yearling.n.02',
#  'ground_sloth.n.01',
#  'megatherian.n.01',
#  'wild_boar.n.01',
#  'swine.n.01',
#  'uakari.n.01',
#  'corgi.n.01',
#  'devon.n.02',
#  'poodle.n.01',
#  'tiger_cat.n.01',
#  'urial.n.01',
#  'common_lynx.n.01',
#  'ocelot.n.01',
#  'potoroo.n.01',
#  'tiger_cub.n.01',
#  'manul.n.01',
#  'yorkshire_terrier.n.01',
#  'fox_terrier.n.01',
#  'white_wolf.n.01',
#  'true_marmoset.n.01',
#  'marmoset.n.01',
#  'pygmy_marmoset.n.01',
#  'pipistrelle.n.01',
#  'vespertilian_bat.n.01',
#  'common_zebra.n.01',
#  'wombat.n.01',
#  'marsupial.n.01',
#  'black_squirrel.n.01',
#  'western_grey_squirrel.n.01',
#  'gaur.n.01',
#  'asian_wild_ox.n.01',
#  'malamute.n.01',
#  'schipperke.n.01',
#  'watchdog.n.02',
#  'kit_fox.n.02',
#  'mouflon.n.01',
#  'spotted_hyena.n.01',
#  'otter.n.02',
#  'saki.n.03',
#  'bowhead.n.01',
#  'onager.n.02',
#  'tibetan_mastiff.n.01',
#  'black-tailed_deer.n.01',
#  'blenheim_spaniel.n.01',
#  'english_toy_spaniel.n.01',
#  'lesser_ape.n.01',
#  'ape.n.01',
#  'field_spaniel.n.01',
#  'giant_schnauzer.n.01',
#  'durham.n.02',
#  'siberian_husky.n.01',
#  'miniature_pinscher.n.01',
#  'pouched_mole.n.01',
#  'metatherian.n.01',
#  'american_water_spaniel.n.01',
#  'spaniel.n.01',
#  'old_world_monkey.n.01',
#  'dall_sheep.n.01',
#  'wild_sheep.n.01',
#  'ibex.n.01',
#  'tamarisk_gerbil.n.01',
#  'pinscher.n.01',
#  'milking_shorthorn.n.01',
#  'schnauzer.n.01',
#  'liver-spotted_dalmatian.n.01',
#  'toy_manchester.n.01',
#  'cape_buffalo.n.01',
#  'australopithecine.n.01',
#  'killer_whale.n.01',
#  'goat.n.01',
#  'horseshoe_bat.n.02',
#  'leafnose_bat.n.01',
#  'cryptoprocta.n.01',
#  'smooth-haired_fox_terrier.n.01',
#  'terrier.n.01',
#  'white-tailed_jackrabbit.n.01',
#  'hedgehog.n.02',
#  'insectivore.n.01',
#  'american_mastodon.n.01',
#  'wheel_horse.n.01',
#  'macaque.n.01',
#  'ayrshire.n.01',
#  'pooch.n.01',
#  'new_world_porcupine.n.01',
#  'gemsbok.n.01',
#  'maltese_dog.n.01',
#  'vervet.n.01',
#  'japanese_spaniel.n.01',
#  'mexican_pocket_mouse.n.01',
#  'stalking-horse.n.04',
#  'ox.n.02',
#  'three-year-old_horse.n.01',
#  'racehorse.n.01',
#  'lakeland_terrier.n.01',
#  'wirehair.n.01',
#  'royal.n.02',
#  'pekinese.n.01',
#  'algeripithecus_minutus.n.01',
#  'hominoid.n.01',
#  'crowbait.n.01',
#  'otterhound.n.01',
#  'panther.n.02',
#  'squirrel_monkey.n.01',
#  'new_world_monkey.n.01',
#  'buckskin.n.01',
#  'solo_man.n.01',
#  'jird.n.01',
#  'hartebeest.n.01',
#  'vaquita.n.01',
#  'dolphin.n.02',
#  'neandertal_man.n.01',
#  'musk_deer.n.01',
#  'common_dolphin.n.01',
#  'whale.n.02',
#  'roebuck.n.01',
#  'afghan_hound.n.01',
#  'masked_shrew.n.01',
#  'shrew.n.02',
#  'rock_squirrel.n.01',
#  'giraffe.n.01',
#  'european_lemming.n.01',
#  'coyote.n.01',
#  'polecat.n.02',
#  'finback.n.01',
#  'cetacean.n.01',
#  'jerboa_kangaroo.n.01',
#  'mountain_gorilla.n.01',
#  'raccoon.n.02',
#  'eastern_cottontail.n.01',
#  'lagomorph.n.01',
#  'hack.n.07',
#  'bettong.n.01',
#  'kangaroo.n.01',
#  'brabancon_griffon.n.01',
#  'mountain_goat.n.01',
#  'pricket.n.02',
#  'carthorse.n.01',
#  'workhorse.n.02',
#  'golden_hamster.n.01',
#  'hamster.n.01',
#  'caribou.n.01',
#  'cur.n.01',
#  'papillon.n.01',
#  'belgian_hare.n.01',
#  'rabbit.n.01',
#  'chestnut.n.06',
#  'kudu.n.01',
#  'great_ape.n.01',
#  'apar.n.01',
#  'edentate.n.01',
#  'stallion.n.01',
#  'male_horse.n.01',
#  'cro-magnon.n.01',
#  'mastiff.n.01',
#  'warhorse.n.03',
#  'saddle_horse.n.01',
#  'welsh_terrier.n.01',
#  'australian_sea_lion.n.01',
#  'meerkat.n.01',
#  'american_bison.n.01',
#  'marco_polo_sheep.n.01',
#  'waterbuck.n.01',
#  'capuchin.n.02',
#  'bighorn.n.02',
#  'soft-coated_wheaten_terrier.n.01',
#  'saiga.n.01',
#  'samoyed.n.03',
#  'seizure-alert_dog.n.01',
#  'mantled_ground_squirrel.n.01',
#  'hound.n.01',
#  'foxhound.n.01',
#  'nude_mouse.n.01',
#  'clydesdale.n.01',
#  'white_rhinoceros.n.01',
#  'whirlaway.n.01',
#  'dingo.n.01',
#  'nanny.n.02',
#  'arabian_camel.n.01',
#  'drill.n.02',
#  'german_short-haired_pointer.n.01',
#  'pointer.n.04',
#  'gerenuk.n.01',
#  'jerboa.n.01',
#  'jerboa_rat.n.01',
#  'musk_ox.n.01',
#  'native_cat.n.01',
#  'little_chief_hare.n.01',
#  'bear_cub.n.01',
#  'beaked_whale.n.01',
#  'ferret_badger.n.01',
#  'english_setter.n.01',
#  'guadalupe_fur_seal.n.01',
#  'australian_terrier.n.01',
#  'antelope.n.01',
#  'anoa.n.01',
#  'welsh_springer_spaniel.n.01',
#  'leporid.n.01',
#  'saint_bernard.n.01',
#  'chacma.n.01',
#  'greyhound.n.01',
#  'bonnet_macaque.n.01',
#  'sealyham_terrier.n.01',
#  'liger.n.01',
#  'wild_goat.n.01',
#  'field_mouse.n.02',
#  'bactrian_camel.n.01',
#  'camel.n.01',
#  'llama.n.01',
#  'norwich_terrier.n.01',
#  'harness_horse.n.01',
#  'santa_gertrudis.n.01',
#  'trotting_horse.n.01',
#  'lhasa.n.02',
#  'post_horse.n.01',
#  'miniature_schnauzer.n.01',
#  'hack.n.08',
#  'blue_point_siamese.n.01',
#  'pika.n.01',
#  'wallaby.n.01',
#  'european_wood_mouse.n.01',
#  'viverrine.n.01',
#  'peking_man.n.01',
#  'sir_barton.n.01',
#  'chesapeake_bay_retriever.n.01',
#  'tortoiseshell.n.03',
#  'golden_retriever.n.01',
#  'mole_rat.n.02',
#  'tayra.n.01',
#  'grey_lemming.n.01',
#  'lemming.n.01',
#  'crabeater_seal.n.01',
#  'dalmatian.n.02',
#  'badger.n.02',
#  'pariah_dog.n.01',
#  'africander.n.01',
#  'australopithecus_africanus.n.01',
#  'mink.n.03',
#  'bronco.n.01',
#  "pere_david's_deer.n.01",
#  'chiacoan_peccary.n.01',
#  'meadow_jumping_mouse.n.01',
#  'jumping_mouse.n.01',
#  'pomeranian.n.01',
#  'south_american_sea_lion.n.01',
#  'pole_horse.n.01',
#  'mountain_paca.n.01',
#  'scottish_deerhound.n.01',
#  'cob.n.02',
#  'chamois.n.02',
#  'glutton.n.02',
#  'hackney.n.02',
#  'curly-coated_retriever.n.01',
#  'boxer.n.04',
#  'dwarf_sperm_whale.n.01',
#  'bedlington_terrier.n.01',
#  'harpy.n.03',
#  'tarpan.n.01',
#  'hazel_mouse.n.01',
#  'california_sea_lion.n.01',
#  'coati.n.01',
#  'giant_kangaroo.n.01',
#  'stablemate.n.01',
#  'red-backed_mouse.n.01',
#  'new_world_least_weasel.n.01',
#  'african_wild_ass.n.01',
#  'harbor_porpoise.n.01',
#  'northern_bog_lemming.n.01',
#  'bullock.n.02',
#  'common_wallaby.n.01',
#  'pacific_bottlenose_dolphin.n.01',
#  'pocketed_bat.n.01',
#  'lioness.n.01',
#  'cairn.n.02',
#  'dormouse.n.01',
#  'zoril.n.01',
#  'viscacha.n.01',
#  'billy.n.02',
#  'morgan.n.06',
#  'american_flying_squirrel.n.01',
#  'toy_poodle.n.01',
#  'cougar.n.01',
#  'aperea.n.01',
#  'eskimo_dog.n.01',
#  'serval.n.01',
#  'leopard_cat.n.01',
#  'american_red_squirrel.n.01',
#  'yellowbelly_marmot.n.01',
#  'marmot.n.01',
#  'red_poll.n.01',
#  'java_man.n.01',
#  'lesser_rorqual.n.01',
#  'guide_dog.n.01',
#  'pygmy_sperm_whale.n.01',
#  'tarsius_syrichta.n.01',
#  'tatouay.n.01',
#  'sloth_bear.n.01',
#  'slow_loris.n.01',
#  'war_admiral.n.01',
#  'kangaroo_rat.n.01',
#  'silky_terrier.n.01',
#  'dhole.n.01',
#  'douroucouli.n.01',
#  'cow.n.01',
#  'crab-eating_dog.n.01',
#  'great_dane.n.01',
#  'cayuse.n.01',
#  'mare.n.01',
#  'bellwether.n.02',
#  'griffon.n.03',
#  'polo_pony.n.01',
#  'sussex_spaniel.n.01',
#  'sorrel.n.05',
#  'pinto.n.01',
#  'northern_pocket_gopher.n.01',
#  'pine_marten.n.01',
#  'kit_fox.n.01',
#  'fox.n.01',
#  'gerbil.n.01',
#  'tapir.n.01',
#  'gnu.n.01',
#  'puku.n.01',
#  'wood_mouse.n.01',
#  'suricate.n.01',
#  'irish_water_spaniel.n.01',
#  'eurasian_hamster.n.01',
#  'suslik.n.01',
#  'silky_anteater.n.01',
#  'appenzeller.n.01',
#  'bird_dog.n.01',
#  'colobus.n.01',
#  'banteng.n.01',
#  'gorilla.n.01',
#  'quagga.n.01',
#  'pocket_rat.n.01',
#  'dik-dik.n.01',
#  'gelding.n.01',
#  'fur_seal.n.01',
#  'pole_horse.n.02',
#  'draft_horse.n.01',
#  'opossum.n.02',
#  'cheviot.n.01',
#  'snow_leopard.n.01',
#  'false_saber-toothed_tiger.n.01',
#  'saber-toothed_tiger.n.01',
#  'wolfhound.n.01',
#  'american_foxhound.n.01',
#  'palfrey.n.01',
#  'margay.n.01',
#  'silverback.n.01',
#  'ice_bear.n.01',
#  'domestic_sheep.n.01',
#  'sheep.n.01',
#  'bull.n.01',
#  'brood_bitch.n.01',
#  'dinocerate.n.01',
#  'shetland_pony.n.01',
#  'ox.n.01',
#  'grade.n.09',
#  'pony.n.02',
#  'pinche.n.01',
#  'monkey.n.01',
#  'fanaloka.n.01',
#  'ermine.n.02',
#  'earless_seal.n.01',
#  'peccary.n.01',
#  'mediterranean_water_shrew.n.01',
#  'water_shrew.n.01',
#  'rhesus.n.01',
#  'hudson_bay_collared_lemming.n.01',
#  'arctic_fox.n.01',
#  'two-year-old_horse.n.01',
#  'italian_greyhound.n.01',
#  'nail-tailed_wallaby.n.01',
#  'prairie_vole.n.01',
#  'chipmunk.n.01',
#  'hampshire.n.02',
#  'assault.n.03',
#  'otter_shrew.n.01',
#  'titi.n.03',
#  'longhorn.n.01',
#  'tarsier.n.01',
#  'indian_mongoose.n.01',
#  'australopithecus_robustus.n.01',
#  'great_pyrenees.n.01',
#  'rogue_elephant.n.01',
#  'potto.n.02',
#  'merino.n.01',
#  'walker_hound.n.01',
#  'central_chimpanzee.n.01',
#  'chimpanzee.n.01',
#  'stone_marten.n.01',
#  'addax.n.01',
#  'black-footed_ferret.n.01',
#  'spearnose_bat.n.01',
#  'gazelle.n.01',
#  'steenbok.n.01',
#  'harp_seal.n.01',
#  'pinniped_mammal.n.01',
#  'bernese_mountain_dog.n.01',
#  'markhor.n.01',
#  'hippopotamus.n.01',
#  'burmese_cat.n.01',
#  'water_chevrotain.n.01',
#  'new_world_tapir.n.01',
#  'tarsius_glis.n.01',
#  'orange_bat.n.01',
#  'bullock.n.01',
#  'weimaraner.n.01',
#  'rambouillet.n.01',
#  'spotted_skunk.n.01',
#  'skunk.n.04',
#  'mastiff_bat.n.01',
#  'pallid_bat.n.01',
#  'omaha.n.04',
#  'lion.n.01',
#  'plains_pocket_gopher.n.01',
#  'redbone.n.01',
#  'groenendael.n.01',
#  'harbor_seal.n.01',
#  'pilot_whale.n.01',
#  'bunny.n.02',
#  'ratel.n.01',
#  'sivapithecus.n.01',
#  'white_whale.n.01',
#  'red_deer.n.01',
#  'percheron.n.01',
#  'tamarin.n.01',
#  'entellus.n.01',
#  'ewe.n.03',
#  'homo_sapiens.n.01',
#  'tree_wallaby.n.01',
#  'new_world_beaver.n.01',
#  'vole.n.01',
#  'moke.n.01',
#  'ass.n.03',
#  'police_dog.n.01',
#  'meadow_vole.n.01',
#  'hoary_marmot.n.01',
#  'plow_horse.n.01',
#  'deer_mouse.n.01',
#  'greater_kudu.n.01',
#  'whitetail_prairie_dog.n.01',
#  'pacer.n.02',
#  'porker.n.01',
#  'doberman.n.01',
#  'american_water_shrew.n.01',
#  'tom.n.02',
#  'wisent.n.01',
#  'alley_cat.n.01',
#  'dusky-footed_woodrat.n.01',
#  'porpoise.n.01',
#  'bison.n.01',
#  'greater_pichiciego.n.01',
#  'pacer.n.01',
#  'gordon_setter.n.01',
#  'pollard.n.02',
#  'anthropoid.n.02',
#  'gazella_subgutturosa.n.01',
#  'digitigrade_mammal.n.01',
#  'marsh_hare.n.01',
#  'homo_erectus.n.01',
#  'fisher.n.02',
#  'brocket.n.02',
#  'lincoln.n.03',
#  'dusky-footed_wood_rat.n.01',
#  'bobcat.n.01',
#  'tailless_tenrec.n.01',
#  'grizzly.n.01',
#  'cow_pony.n.01',
#  'muskrat.n.02',
#  'boarhound.n.01',
#  'cheetah.n.01',
#  'hart.n.03',
#  'bluetick.n.01',
#  'barbary_ape.n.01',
#  'golden_mole.n.01',
#  'rice_rat.n.01',
#  'langur.n.01',
#  'snowshoe_hare.n.01',
#  'puppy.n.01',
#  'hispid_pocket_mouse.n.01',
#  'lemur.n.01',
#  'mouser.n.01',
#  'domestic_goat.n.01',
#  'irish_terrier.n.01',
#  'charger.n.01',
#  'patas.n.01',
#  'mustang.n.01',
#  'american_shrew_mole.n.01',
#  'mole.n.06',
#  'malinois.n.01',
#  'malayan_tapir.n.01',
#  'broodmare.n.01',
#  'abrocome.n.01',
#  'shire.n.02',
#  'eastern_pipistrel.n.01',
#  'aardwolf.n.01',
#  'vizsla.n.01',
#  'border_terrier.n.01',
#  'saluki.n.01',
#  'tibetan_terrier.n.01',
#  'world.n.08',
#  'angora.n.03',
#  'skye_terrier.n.01',
#  'cave_myotis.n.01',
#  'angora.n.02',
#  'imperial_mammoth.n.01',
#  'pachyderm.n.01',
#  'beagle.n.01',
#  'alpaca.n.03',
#  'zebra.n.01',
#  'large_civet.n.01',
#  'civet.n.01',
#  'pocket_mouse.n.01',
#  'atlantic_walrus.n.01',
#  'water_vole.n.01',
#  'irish_setter.n.01',
#  'blacktail_prairie_dog.n.01',
#  'basenji.n.01',
#  'american_black_bear.n.01',
#  'stud.n.04',
#  'lesser_kudu.n.01',
#  'cotswold.n.01',
#  'jackass_bat.n.01',
#  'goral.n.01',
#  'european_wildcat.n.01',
#  'gib.n.02',
#  'ferret.n.02',
#  'sausage_dog.n.01',
#  'hog.n.03',
#  'nonstarter.n.02',
#  'sea_lion.n.01',
#  'sperm_whale.n.01',
#  'zinjanthropus.n.01',
#  'big-eared_bat.n.01',
#  'silky_pocket_mouse.n.01',
#  'false_vampire.n.01',
#  'asiatic_black_bear.n.01',
#  'coydog.n.01',
#  'muntjac.n.01',
#  'crab-eating_opossum.n.01',
#  'norwegian_elkhound.n.01',
#  'rock_wallaby.n.01',
#  'vixen.n.02',
#  'canada_lynx.n.01',
#  'dun.n.01',
#  'count_fleet.n.01',
#  'elk.n.01',
#  'flat-coated_retriever.n.01',
#  'retriever.n.01',
#  'arabian.n.02',
#  'lucy.n.01',
#  'spouter.n.03',
#  'mule_deer.n.01',
#  'kelpie.n.02',
#  'sled_dog.n.01',
#  'gayal.n.01',
#  'eastern_chimpanzee.n.01',
#  'oryx.n.01',
#  'napu.n.01',
#  'brown_rat.n.01',
#  'mylodontid.n.01',
#  'collared_peccary.n.01',
#  'wolf.n.01',
#  'sinanthropus.n.01',
#  'western_pipistrel.n.01',
#  'silver_fox.n.01',
#  'echidna.n.01',
#  'sand_rat.n.01',
#  'seeing_eye_dog.n.01',
#  'cinnamon_bear.n.01',
#  'okapi.n.01',
#  'wether.n.01',
#  'blackbuck.n.01',
#  'vicuna.n.03',
#  'serow.n.01',
#  'razorback.n.01',
#  'grampus.n.02',
#  'tennessee_walker.n.01',
#  'typical_jerboa.n.01',
#  'african_elephant.n.01',
#  'slender_loris.n.01',
#  'mule.n.01',
#  'western_chimpanzee.n.01',
#  'spider_monkey.n.01',
#  'indian_elephant.n.01',
#  'bandicoot_rat.n.01',
#  'paranthropus.n.01',
#  'cardigan.n.02',
#  'rat_kangaroo.n.01',
#  'pine_vole.n.01',
#  'stirk.n.01',
#  'agouti.n.01',
#  'american_harvest_mouse.n.01',
#  'ibizan_hound.n.01',
#  'groundhog.n.01',
#  'flying_mouse.n.01',
#  'homo_soloensis.n.01',
#  'giant_armadillo.n.01',
#  'bull.n.11',
#  'warrigal.n.01',
#  'pembroke.n.01',
#  'border_collie.n.01',
#  "brewer's_mole.n.01",
#  'gallant_fox.n.01',
#  'black_fox.n.01',
#  'broadtail.n.02',
#  'eastern_woodrat.n.01',
#  'sow.n.01',
#  'old_world_beaver.n.01',
#  'pouched_mouse.n.01',
#  'brittany_spaniel.n.01',
#  'hog-nosed_skunk.n.01',
#  'rudapithecus.n.01',
#  'staghound.n.01',
#  'genet.n.03',
#  'river_dolphin.n.01',
#  'kid.n.05',
#  'green_monkey.n.01',
#  'white-lipped_peccary.n.01',
#  'rabbit-eared_bandicoot.n.01',
#  'phyllostomus_hastatus.n.01',
#  'murine.n.01',
#  'dryopithecine.n.01',
#  'setter.n.02',
#  'manatee.n.01',
#  'sea_cow.n.01',
#  'impala.n.01',
#  'mammoth.n.01',
#  'water_spaniel.n.01',
#  'hare_wallaby.n.01',
#  'mongoose.n.01',
#  'toy_terrier.n.01',
#  'labrador_retriever.n.01',
#  'red_fox.n.02',
#  'bengal_tiger.n.01',
#  'coondog.n.01',
#  'chickeree.n.01',
#  'short-tailed_shrew.n.01',
#  'rabbit_ears.n.02',
#  'round-tailed_muskrat.n.01',
#  'serotine.n.01',
#  'wharf_rat.n.02',
#  'domestic_llama.n.01',
#  'platypus.n.01',
#  'kinkajou.n.01',
#  'swamp_rabbit.n.02',
#  'new_world_mouse.n.01',
#  'kerry_blue_terrier.n.01',
#  'appaloosa.n.01',
#  'brush-tailed_phalanger.n.01',
#  'lerot.n.01',
#  'grey_fox.n.01',
#  'southern_flying_squirrel.n.01',
#  'carabao.n.01',
#  'bitch.n.04',
#  'sand_cat.n.01',
#  'black_sheep.n.02',
#  'tigress.n.01',
#  'tiger.n.02',
#  'slender-tailed_meerkat.n.01',
#  'heifer.n.01',
#  'pygmy_mouse.n.01',
#  'alaska_fur_seal.n.01',
#  'attack_dog.n.01',
#  'quarter_horse.n.01',
#  'white-footed_mouse.n.01',
#  'eastern_lowland_gorilla.n.01',
#  'bottlenose_dolphin.n.01',
#  'coypu.n.01',
#  'tabby.n.02',
#  'remount.n.01',
#  'house_mouse.n.01',
#  'guinea_pig.n.02',
#  'cavy.n.01',
#  'black-and-tan_coonhound.n.01',
#  'brown_bat.n.01',
#  'dandie_dinmont.n.01',
#  'gibbon.n.02',
#  'boskop_man.n.01',
#  'anteater.n.02',
#  'smiledon_californicus.n.01',
#  'right_whale.n.01',
#  'chigetai.n.01',
#  'wild_ass.n.01',
#  'simian.n.01',
#  'kangaroo_mouse.n.02',
#  'woolly_monkey.n.01',
#  'black_rat.n.01',
#  'common_shrew.n.01',
#  'french_bulldog.n.01',
#  'leopardess.n.01',
#  'kiang.n.01',
#  'dasyurid_marsupial.n.01',
#  'peludo.n.01',
#  'grasshopper_mouse.n.01',
#  'pied_lemming.n.01',
#  'packhorse.n.01',
#  'bullterrier.n.01',
#  'elephant.n.01',
#  'wolverine.n.03',
#  'capybara.n.01',
#  'tree_squirrel.n.01',
#  'sambar.n.01',
#  'bongo.n.02',
#  'binturong.n.01',
#  'jaguarundi.n.01',
#  'hooded_seal.n.01',
#  'friesian.n.01',
#  'argali.n.01',
#  'liver_chestnut.n.01',
#  'flying_fox.n.01',
#  'striped_skunk.n.01',
#  'american_mink.n.01',
#  'galago.n.01',
#  'arctic_ground_squirrel.n.01',
#  'zebu.n.01',
#  'blacktail_jackrabbit.n.01',
#  'caracal.n.01',
#  'bloodhound.n.01',
#  'guereza.n.01',
#  'keeshond.n.01',
#  'chevrotain.n.01',
#  'snake_muishond.n.01',
#  'southern_bog_lemming.n.01',
#  'grey_whale.n.01',
#  'javanthropus.n.01',
#  'brown_swiss.n.01',
#  'rhodesian_ridgeback.n.01',
#  'newfoundland.n.01',
#  'dinoceras.n.01',
#  'homo_sapiens_sapiens.n.01',
#  'coonhound.n.01',
#  'eastern_grey_squirrel.n.01',
#  'proconsul.n.03',
#  'clumber.n.01',
#  'egyptian_cat.n.01',
#  'manchester_terrier.n.01',
#  'aardvark.n.01',
#  'humpback.n.03',
#  'pentail.n.01',
#  'tree_shrew.n.01',
#  'feist.n.01',
#  'cashmere_goat.n.01',
#  'hog_badger.n.01',
#  'crab-eating_raccoon.n.01',
#  'red_fox.n.03',
#  'american_saddle_horse.n.01',
#  'frosted_bat.n.01',
#  'little_brown_bat.n.01',
#  "thomson's_gazelle.n.01",
#  'fox_squirrel.n.01',
#  'pronghorn.n.01',
#  'ichneumon.n.01',
#  'greater_swiss_mountain_dog.n.01',
#  'mapinguari.n.01',
#  'roe_deer.n.01',
#  "steller's_sea_cow.n.01",
#  'european_rabbit.n.01',
#  'white_elephant.n.02',
#  'blue_fox.n.01',
#  'blue_whale.n.01',
#  'aoudad.n.01',
#  'orangutan.n.01',
#  'atlantic_bottlenose_dolphin.n.01',
#  'japanese_deer.n.01',
#  'asiatic_shrew_mole.n.01',
#  'queen.n.09',
#  'walrus.n.01',
#  'kob.n.01',
#  'starnose_mole.n.01',
#  'crab-eating_macaque.n.01',
#  'pteropus_hypomelanus.n.01',
#  'spotted_lynx.n.01',
#  'brahman.n.04',
#  'ram.n.05',
#  'talapoin.n.01',
#  'prancer.n.01',
#  ...]

# %%
lt_np = lt.numpy()
plt.scatter(lt_np[:,0], lt_np[:,1])

# %%
chkpnt = torch.load('results/2d/mammals.pth', map_location='cpu')
lt = chkpnt['embeddings']
lt_np = lt.numpy()
plt.scatter(lt_np[:,0], lt_np[:,1])

# %%
chkpnt = torch.load('results/2d/mammals.pth', map_location='cpu')
lt = chkpnt['embeddings']
lt_np = lt.numpy()

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111)
ax.scatter(lt_np[:,0], lt_np[:,1])
ax.set_aspect('equal')

# %%
meanrank, maprank = eval_reconstruction(adj, lt, manifold.distance)
# Out:
# --------------------------------------------------------------------------
# NameError                                Traceback (most recent call last)
# <ipython-input-4-a1a3b10c2cf0> in <module>
# ----> 1 meanrank, maprank = eval_reconstruction(adj, lt, manifold.distance)
#
# NameError: name 'adj' is not defined
